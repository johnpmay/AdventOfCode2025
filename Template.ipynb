# %%
from pathlib import Path
from time import time

input_file = Path('../../AdventOfCode_inputs/AoC-2025-XX-input.txt')

rinput = input_file.read_text()

# %%
sinput = '''
'''

# %%
ainput = sinput

# %% [markdown]
# **Part One**

# %%
startTime = time()

time()-startTime

# %%
ans1

# %% [markdown]
# **Part Two**

# %%
startTime = time()

time()-startTime

# %%
ans2
